# %% [markdown]
# <h2 style='color:green'> Under sampling majority class <h2>

# %% [markdown]
# ![Screenshot%202023-06-12%20at%2015.29.48.png](attachment:Screenshot%202023-06-12%20at%2015.29.48.png)

# %% [markdown]
# <h2 style='color:green'> Over sampling minority class by duplication <h2>

# %% [markdown]
# ![Screenshot%202023-06-12%20at%2015.31.56.png](attachment:Screenshot%202023-06-12%20at%2015.31.56.png)

# %% [markdown]
# <h2 style='color:green'> Over sampling minority class by SMOTE <h2>

# %% [markdown]
# ![Screenshot%202023-06-12%20at%2015.35.27.png](attachment:Screenshot%202023-06-12%20at%2015.35.27.png)

# %% [markdown]
# <h2 style='color:green'> Ensemble method <h2>

# %% [markdown]
# ![Screenshot%202023-06-12%20at%2015.40.00.png](attachment:Screenshot%202023-06-12%20at%2015.40.00.png)

# %% [markdown]
# <h2 style='color:green'> Focal loss <h2>

# %% [markdown]
# ![Screenshot%202023-06-12%20at%2015.43.07.png](attachment:Screenshot%202023-06-12%20at%2015.43.07.png)
