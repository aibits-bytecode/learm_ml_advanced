# %% [markdown]
# <h3 style='color:blue'> Mean Abasolute Error </h3>

# %% [markdown]
# ![Screenshot%202023-06-06%20at%2016.27.19.png](attachment:Screenshot%202023-06-06%20at%2016.27.19.png)

# %% [markdown]
# <h3 style='color:blue'> Squared Error </h3>

# %% [markdown]
# ![Screenshot%202023-06-06%20at%2016.28.53.png](attachment:Screenshot%202023-06-06%20at%2016.28.53.png)

# %% [markdown]
# Squarred Error works in Gradientdecent better way

# %% [markdown]
# <h3 style='color:blue'> Log loss or Binary cross entropy </h3>

# %% [markdown]
# ![Screenshot%202023-06-06%20at%2020.04.02.png](attachment:Screenshot%202023-06-06%20at%2020.04.02.png)

# %% [markdown]
# <h2> How loss functions work </h2>

# %%
import numpy as np

y_predicted = np.array([1,1,0,0,1])
y_true = np.array([0.30,0.7,1,0,0.5])

# %% [markdown]
# <h3 style='color:blue'> Implement Mean Absolute Error </h3>

# %%
def mae(y_true, y_predicted):
    total_error = 0
    for yt,yp in zip(y_true,y_predicted):
        total_error += abs(yt - yp)
    print("Total error : ", total_error)    
    mae = total_error/len(y_true)
    print("MAE :", mae)
    return mae

mae(y_true, y_predicted)
# Out:
# Total error :  2.5
# MAE : 0.5
# 0.5

# %%
print("total error : ", np.sum(np.abs(y_predicted - y_true)))
print("MAE : ", np.mean(np.abs(y_predicted - y_true)))
# Out:
# total error :  2.5
# MAE :  0.5

# %% [markdown]
# <h3 style='color:blue'> Implement Mean Squared Error </h3>

# %%
def mse(y_true, y_predicted):
    total_error = 0
    for yt,yp in zip(y_true,y_predicted):
        total_error += (yt - yp)**2
    print("Total error : ", total_error)    
    mse = total_error/len(y_true)
    print("MSE :", mse)
    return mse

mae(y_true, y_predicted)
# Out:
# Total error :  1.83
# MAE : 0.366
# 0.366

# %%
print("total error : ", np.sum(np.square(y_predicted - y_true)))
print("MSE : ", np.mean(np.square(y_predicted - y_true)))
# Out:
# total error :  1.83
# MSE :  0.366

# %% [markdown]
# <h3 style='color:blue'> Log loss </h3>

# %% [markdown]
# ![Screenshot%202023-06-06%20at%2020.04.02.png](attachment:Screenshot%202023-06-06%20at%2020.04.02.png)

# %% [markdown]
# <p style='color:yellow'>
# In here there is a problem log(0) is infinite
# </p>

# %%
np.log(0)
# Out:
# /var/folders/bt/yzv722jd4ln6fj7873tf5mn00000gn/T/ipykernel_81566/2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
epsilon = 1e-15

# %%
y_predicted_new = [max(i,epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean((y_true*np.log(y_predicted_new))+(1- y_true)*np.log(1-y_predicted_new))
# Out:
# 17.2696280766844

# %%
def log_loss(y_true,y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean((y_true*np.log(y_predicted_new))+(1- y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true,y_predicted)
# Out:
# 17.2696280766844
