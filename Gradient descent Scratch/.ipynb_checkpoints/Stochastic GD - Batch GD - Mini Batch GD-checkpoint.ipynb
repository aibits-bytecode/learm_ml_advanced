# %% [markdown]
# ![Screenshot%202023-06-08%20at%2022.22.16.png](attachment:Screenshot%202023-06-08%20at%2022.22.16.png)

# %% [markdown]
# ![Screenshot%202023-06-08%20at%2022.24.39.png](attachment:Screenshot%202023-06-08%20at%2022.24.39.png)

# %% [markdown]
# ![Screenshot%202023-06-08%20at%2022.26.01.png](attachment:Screenshot%202023-06-08%20at%2022.26.01.png)

# %%
import pandas as pd
df = pd.read_csv('./homeprices.csv')
df.head()
# Out:
#    area  bedrooms   price
# 0  1056         2   39.07
# 1  2600         4  120.00
# 2  1440         3   62.00
# 3  1521         3   75.00
# 4  1200         2   51.00

# %%
df.isna().sum()
# Out:
# area        0
# bedrooms    0
# price       0
# dtype: int64

# %% [markdown]
# <h2 style='color:blue'> Scale data </h2>

# %%
from sklearn import preprocessing
sx = preprocessing.MinMaxScaler()
sy = preprocessing.MinMaxScaler()
