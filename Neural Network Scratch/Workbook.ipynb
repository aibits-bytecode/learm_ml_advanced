# %% [markdown]
# <h2 style='color:blue'> Loading data </h2>

# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('./insurance_data.csv')
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
df.isna().sum()
# Out:
# age                 0
# affordibility       0
# bought_insurance    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age','affordibility']], df.bought_insurance, test_size=0.2, random_state=25)

# %%
x_train.shape
# Out:
# (22, 2)

# %%
x_train.head()
# Out:
#     age  affordibility
# 0    22              1
# 13   29              0
# 6    55              0
# 17   58              1
# 24   50              1

# %% [markdown]
# <h2 style='color:blue'> Scaling data </h2>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
x_train_scaled = x_train
x_test_scaled = x_test

# %%
x_train_scaled['age'] = scaler.fit_transform(x_train_scaled[['age']])
x_train_scaled.head()
# Out:
#          age  affordibility
# 0   0.090909              1
# 13  0.250000              0
# 6   0.840909              0
# 17  0.909091              1
# 24  0.727273              1

# %%
x_train.head()
# Out:
#          age  affordibility
# 0   0.090909              1
# 13  0.250000              0
# 6   0.840909              0
# 17  0.909091              1
# 24  0.727273              1

# %%
x_train_scale = x_train
x_test_scale = x_test
x_train_scale.age = x_train_scale.age/100
x_test_scale.age = x_test_scale.age/100

# %%
x_train_scale.head()
# Out:
#      age  affordibility
# 0   0.22              1
# 13  0.29              0
# 6   0.55              0
# 17  0.58              1
# 24  0.50              1

# %% [markdown]
# <h2 style='color:blue'> Building Neural network </h2>

# %%
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_scaled,y_train, epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6784 - accuracy: 0.5000
# Epoch 2/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6782 - accuracy: 0.5455
# Epoch 3/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6780 - accuracy: 0.5455
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6778 - accuracy: 0.6364
# Epoch 5/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6776 - accuracy: 0.6364
# Epoch 6/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6774 - accuracy: 0.6364
# Epoch 7/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.6364
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6770 - accuracy: 0.6364
# Epoch 9/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.6818
# Epoch 10/5000
# ...

# %%
model.evaluate(x_test_scaled,y_test)
# Out:
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8920 - accuracy: 0.5000
# [0.891986072063446, 0.5]

# %%
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_scale,y_train, epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.7113 - accuracy: 0.5000
# Epoch 2/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7110 - accuracy: 0.5000
# Epoch 3/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7106 - accuracy: 0.5000
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7102 - accuracy: 0.5000
# Epoch 5/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7098 - accuracy: 0.5000
# Epoch 6/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7094 - accuracy: 0.5000
# Epoch 7/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7091 - accuracy: 0.5000
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7087 - accuracy: 0.5000
# Epoch 9/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7083 - accuracy: 0.5000
# Epoch 10/5000
# ...

# %%
model.evaluate(x_test_scale,y_test)
# Out:
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3550 - accuracy: 1.0000
# [0.35497748851776123, 1.0]

# %%
coef, intercept = model.get_weights()
coef, intercept
# Out:
# (array([[5.060867 ],
#         [1.4086502]], dtype=float32),
#  array([-2.9137027], dtype=float32))

# %%
x_test_scale
# Out:
#      age  affordibility
# 2   0.47              1
# 10  0.18              1
# 21  0.26              0
# 11  0.28              1
# 14  0.49              1
# 9   0.61              1

# %%
model.predict(x_test_scale)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[0.70548487],
#        [0.35569552],
#        [0.16827849],
#        [0.47801173],
#        [0.7260697 ],
#        [0.82949835]], dtype=float32)

# %% [markdown]
# <h2 style='color:blue'> Lets try to build NN from scratch </h2>

# %%
def sigmoid(x):
    import math
    return 1/(1 + math.exp(-x))

sigmoid(10)
# Out:
# 0.9999546021312976

# %%
def prediction_function(age, affordibility):
     # weight1*age + weight2*affordability + bias
    weighted_sum = coef[0]*age + coef[1]*affordibility + intercept
    return sigmoid(weighted_sum)

# %%
prediction_function(0.47,1)
# Out:
# 0.7054848693136117

# %%
def log_loss(y_true,y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean((y_true*np.log(y_predicted_new))+(1- y_true)*np.log(1-y_predicted_new))

# %%
import numpy as np
def sigmoid_numpy(x):
    return 1/(1+np.exp(-x))
sigmoid_numpy(np.array([12,0,1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %% [markdown]
# ![Screenshot%202023-06-08%20at%2018.31.18.png](attachment:Screenshot%202023-06-08%20at%2018.31.18.png)

# %%
def gradient_descent(age, affordability, y_true, epochs, loss_threshold):
    # we are going to find w1,w2 and bias
    w1=w2=1
    bias=0
    rate = 0.5
    n = len(age)
    
    for i in range(epochs):
        weighted_sum = w1*age + w2*affordability + bias
        y_predicted = sigmoid_numpy(weighted_sum)
        loss = log_loss(y_true,y_predicted)
        w1derivative = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
        w2derivative = (1/n)*np.dot(np.transpose(affordability),(y_predicted-y_true))
        bias_derivative = np.mean(y_predicted-y_true)
        
        w1 = w1-rate*w1derivative
        w2 = w2 - rate*w2derivative
        bias = bias - rate * bias_derivative
        
        print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
        
        if loss<=loss_threshold:
            break
    return w1,w2,bias

# %%
gradient_descent(x_train_scale['age'],x_train_scale['affordibility'],y_train, 1000, 0.4633)
# Out:
# Epoch:0, w1:0.974907633470177, w2:0.948348125394529, bias:-0.11341867736368583, loss:0.7113403233723417
# Epoch:1, w1:0.9556229728273669, w2:0.9058873696677865, bias:-0.2122349122718517, loss:0.681264778737757
# Epoch:2, w1:0.9416488476693794, w2:0.8719790823960313, bias:-0.2977578997796538, loss:0.6591474252715025
# Epoch:3, w1:0.9323916996249162, w2:0.8457541517722915, bias:-0.3715094724003511, loss:0.6431523291301917
# Epoch:4, w1:0.9272267472726993, w2:0.8262362885332687, bias:-0.43506643026891584, loss:0.6316873063379158
# Epoch:5, w1:0.9255469396815343, w2:0.8124402814952774, bias:-0.48994490058938817, loss:0.623471707997592
# Epoch:6, w1:0.9267936114129968, w2:0.8034375029757677, bias:-0.5375299543522853, loss:0.6175321183044205
# Epoch:7, w1:0.93047170420295, w2:0.7983920007454487, bias:-0.5790424270894963, loss:0.6131591858705934
# Epoch:8, w1:0.9361540784567942, w2:0.7965748796787705, bias:-0.6155315088627655, loss:0.6098518179750948
# ...

# %%
 coef, intercept
# Out:
# (array([[5.060867 ],
#         [1.4086502]], dtype=float32),
#  array([-2.9137027], dtype=float32))

# %% [markdown]
# ## Creation of NN

# %% [markdown]
# <p style='color:green'>
#     What we need at last is : <br>
#     ~ customModel = myNN() <br>
#     ~ customModel.fit(x_train_scaled, y_train, epochs=500, loss_thresold=0.4631) <br>
#     ~ customModel.predict(x_test_scale)
# </p>

# %%
class myNN:
    def __init__(self):
        self.w1 = 1
        self.w2 = 1
        self.bias = 0
    
    def fit(self, x, y, epochs, loss_threshold):
        self.w1, self.w2, self.bias =  self.gradient_descent(x['age'], x['affordibility'], y, epochs, loss_threshold)
    
    def predict(self, x):
        weighted_sum = self.w1*x['age'] + self.w2*x['affordibility'] + self.bias
        return self.sigmoid_numpy(weighted_sum)
        
    
    def sigmoid_numpy(self, x):
        import numpy as np
        return 1/(1+np.exp(-x))
    
    def gradient_descent(self, age, affordibility, y_true, epochs, loss_threshold):
        # we are going to find w1,w2 and bias
        w1=w2=1
        bias=0
        rate = 0.5
        n = len(age)
    
        for i in range(epochs):
            weighted_sum = w1*age + w2*affordibility + bias
            y_predicted = sigmoid_numpy(weighted_sum)
            loss = log_loss(y_true,y_predicted)
            w1derivative = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
            w2derivative = (1/n)*np.dot(np.transpose(affordibility),(y_predicted-y_true))
            bias_derivative = np.mean(y_predicted-y_true)

            w1 = w1-rate*w1derivative
            w2 = w2 - rate*w2derivative
            bias = bias - rate * bias_derivative

            print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')

            if loss<=loss_threshold:
                break
        return w1,w2,bias

# %%
model = myNN()
model.fit(x_train_scale, y_train, 1000, 0.4633)
# Out:
# Epoch:0, w1:0.974907633470177, w2:0.948348125394529, bias:-0.11341867736368583, loss:0.7113403233723417
# Epoch:1, w1:0.9556229728273669, w2:0.9058873696677865, bias:-0.2122349122718517, loss:0.681264778737757
# Epoch:2, w1:0.9416488476693794, w2:0.8719790823960313, bias:-0.2977578997796538, loss:0.6591474252715025
# Epoch:3, w1:0.9323916996249162, w2:0.8457541517722915, bias:-0.3715094724003511, loss:0.6431523291301917
# Epoch:4, w1:0.9272267472726993, w2:0.8262362885332687, bias:-0.43506643026891584, loss:0.6316873063379158
# Epoch:5, w1:0.9255469396815343, w2:0.8124402814952774, bias:-0.48994490058938817, loss:0.623471707997592
# Epoch:6, w1:0.9267936114129968, w2:0.8034375029757677, bias:-0.5375299543522853, loss:0.6175321183044205
# Epoch:7, w1:0.93047170420295, w2:0.7983920007454487, bias:-0.5790424270894963, loss:0.6131591858705934
# Epoch:8, w1:0.9361540784567942, w2:0.7965748796787705, bias:-0.6155315088627655, loss:0.6098518179750948
# ...

# %%
model.predict(x_test_scale)
# Out:
# 2     0.704793
# 10    0.356683
# 21    0.161996
# 11    0.478430
# 14    0.725303
# 9     0.828504
# dtype: float64
